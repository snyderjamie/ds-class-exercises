# %% [markdown]
# ![rmotr](https://i.imgur.com/jiPp4hj.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrames additional exercises
# ![separator2](https://i.imgur.com/4gX5WFr.png)

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 0.23.0

# %% [markdown]
# ![separator1](https://i.imgur.com/ZUWYTii.png)
#
# ## DataFrames creation

# %%
# Create an empty pandas DataFrame

D = pd.DataFrame()
print(D, type(D))

# pd.DataFrame(data=[None],
#              index=[None],
#              columns=[None])
# Out:
# Empty DataFrame
# Columns: []
# Index: [] <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %%
# Create a marvel_df pandas DataFrame with the given marvel data
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

marvel_df = pd.DataFrame.from_records(marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
# Add column names to the marvel_df
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %%
# Add index names to the marvel_df (use the character name as index)

marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %%
# Drop the name column as it's now the index

marvel_df = marvel_df.drop(columns='name')
# marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
# Drop 'Namor' and 'Hank Pym' rows

marvel_df.drop(['Namor', 'Hank Pym'])
# marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![separator1](https://i.imgur.com/ZUWYTii.png)
#
# ## DataFrames selection, slicing and indexation

# %%
# Show the first 5 elements on marvel_df

# marvel_df.loc['Spider-Man': 'Thor']
# marvel_df.iloc[:5]
marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
# Show the last 5 elements on marvel_df

# marvel_df.iloc[-5:]
marvel_df.tail()
# Out:
#                   sex  first_appearance
# name
# Hank Pym         male              1962
# Scarlet Witch  female              1964
# Wasp           female              1963
# Black Widow    female              1964
# Vision           male              1968

# %%
# Show just the sex of the first 5 elements on marvel_df

marvel_df.iloc[:5, 0]
# marvel_df.head().sex.to_frame()
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
# Show the first_appearance of all middle elements on marvel_df

# middle being the middle 50%
marvel_df.iloc[3:13,1]
# marvel_df.iloc[1:-1,].first_appearance.to_frame()
# Out:
# name
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Namor               1939
# Hawkeye             1964
# Name: first_appearance, dtype: int64

# %%
# Show the first and last elements on marvel_df

marvel_df.iloc[[0,-1]]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %% [markdown]
# ![separator1](https://i.imgur.com/ZUWYTii.png)
#
# ## DataFrames manipulation and operations

# %%
# Modify the first_appearance of 'Vision' to year 1964

marvel_df.at['Vision', 'first_appearance'] = 1964
# marvel_df.loc['Vision', 'first_appearance'] = 1964
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1964

# %%
# Add a new column to marvel_df called 'years_since' with the years since first_appearance

marvel_df['years_since'] = 2019 - marvel_df['first_appearance']
marvel_df.head()
# Out:
#                   sex  first_appearance  years_since
# name
# Spider-Man       male              1962           57
# Captain America  male              1941           78
# Wolverine        male              1974           45
# Iron Man         male              1963           56
# Thor             male              1963           56

# %% [markdown]
# ![separator1](https://i.imgur.com/ZUWYTii.png)
#
# ## DataFrames boolean arrays (also called masks)

# %%
# Given the marvel_df pandas DataFrame, make a mask showing the female characters

marvel_df['sex'] == 'female'
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
# Given the marvel_df pandas DataFrame, get the male characters

marvel_df[marvel_df['sex'] == 'male']
# Out:
#                    sex  first_appearance  years_since
# name
# Spider-Man        male              1962           57
# Captain America   male              1941           78
# Wolverine         male              1974           45
# Iron Man          male              1963           56
# Thor              male              1963           56
# Thing             male              1961           58
# Mister Fantastic  male              1961           58
# Hulk              male              1962           57
# Beast             male              1963           56
# Namor             male              1939           80
# Hawkeye           male              1964           55
# Daredevil         male              1964           55
# Doctor Strange    male              1963           56
# Hank Pym          male              1962           57
# Vision            male              1964           55

# %%
# Given the marvel_df pandas DataFrame, get the characters with first_appearance after 1970

marvel_df[marvel_df['first_appearance'] > 1970]
# Out:
#               sex  first_appearance  years_since
# name
# Wolverine    male              1974           45
# Storm      female              1975           44

# %%
# Given the marvel_df pandas DataFrame, get the female characters with first_appearance after 1970

marvel_df[(marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)]
# Out:
#           sex  first_appearance  years_since
# name
# Storm  female              1975           44

# %% [markdown]
# ![separator1](https://i.imgur.com/ZUWYTii.png)
#
# ## DataFrames summary statistics

# %%
# Show basic statistics of marvel_df

marvel_df.info()
marvel_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Spider-Man to Vision
# Data columns (total 3 columns):
# sex                 20 non-null object
# first_appearance    20 non-null int64
# years_since         20 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB
#        first_appearance  years_since
# count         20.000000    20.000000
# mean        1961.650000    57.350000
# std            8.298859     8.298859
# min         1939.000000    44.000000
# 25%         1961.750000    55.000000
# 50%         1963.000000    56.000000
# 75%         1964.000000    57.250000
# max         1975.000000    80.000000

# %%
# Given the marvel_df pandas DataFrame, show the mean value of first_appearance

marvel_df['first_appearance'].mean()
# marvel_df.first_appearance.mean()
# Out:
# 1961.65

# %%
# Given the marvel_df pandas DataFrame, show the min value of first_appearance

marvel_df['first_appearance'].min()
# marvel_df.first_appearance.min()
# Out:
# 1939

# %%
# Given the marvel_df pandas DataFrame, get the characters with the min value of first_appearance

marvel_df['first_appearance'].idxmin()

# mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
# marvel_df[mask]
# Out:
# 'Namor'

# %% [markdown]
# ![separator1](https://i.imgur.com/ZUWYTii.png)
#
# ## DataFrames basic plottings

# %%
# Reset the index names

marvel_df = marvel_df.reset_index()

# %%
marvel_df
# Out:
#                 name     sex  first_appearance  years_since
# 0         Spider-Man    male              1962           57
# 1    Captain America    male              1941           78
# 2          Wolverine    male              1974           45
# 3           Iron Man    male              1963           56
# 4               Thor    male              1963           56
# 5              Thing    male              1961           58
# 6   Mister Fantastic    male              1961           58
# 7               Hulk    male              1962           57
# 8              Beast    male              1963           56
# 9    Invisible Woman  female              1961           58
# 10             Storm  female              1975           44
# 11             Namor    male              1939           80
# 12           Hawkeye    male              1964           55
# 13         Daredevil    male              1964           55
# 14    Doctor Strange    male              1963           56
# 15          Hank Pym    male              1962           57
# 16     Scarlet Witch  female              1964           55
# 17              Wasp  female              1963           56
# 18       Black Widow  female              1964           55
# 19            Vision    male              1964           55

# %%
# Plot the values of first_appearance

marvel_df.first_appearance.plot()

# %%
# Plot a histogram (plot.hist) with values of first_appearance

fig, axes = plt.subplots(figsize=(12, 6))
plt.hist(marvel_df.first_appearance, bins=50, alpha=0.8,
          histtype='bar', color='powderblue',
          edgecolor='steelblue')
plt.title('First Appearance of Marvel Characters', fontsize=20)
plt.xlabel('Year')
plt.ylabel('Number of Characters')
# Out:
# Text(0,0.5,'Number of Characters')

# %% [markdown]
# ![separator2](https://i.imgur.com/4gX5WFr.png)
